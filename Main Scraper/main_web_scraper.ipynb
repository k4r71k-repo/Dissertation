# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.11.2-py2.py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 4.3 MB/s eta 0:00:00
# Collecting Twisted>=18.9.0 (from scrapy)
#   Downloading twisted-24.3.0-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (42.0.7)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.3.0-py3-none-any.whl (12 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.9.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (24.1.0)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.7.0-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-24.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.4.post2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 15.0 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.3.1-py2.py3-none-any.whl (8.5 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.9.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from scrapy) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scrapy) (24.0)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from scrapy) (4.9.4)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from scrapy) (0.7.1)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (23.2.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.6.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.0)
# Collecting automat>=0.8.0 (from Twisted>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting constantly>=15.1 (from Twisted>=18.9.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.8 MB/s eta 0:00:00
# Collecting incremental>=22.10.0 (from Twisted>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from Twisted>=18.9.0->scrapy) (4.11.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.7)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.14.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from automat>=0.8.0->Twisted>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2024.2.2)
# Installing collected packages: PyDispatcher, incremental, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, constantly, automat, Twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed PyDispatcher-2.0.7 Twisted-24.3.0 automat-22.10.0 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.9.0 itemloaders-1.3.0 jmespath-1.0.1 parsel-1.9.1 protego-0.3.1 queuelib-1.7.0 requests-file-2.1.0 scrapy-2.11.2 service-identity-24.1.0 tldextract-5.1.2 w3lib-2.1.2 zope.interface-6.4.post2

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.http import Request
from itemloaders.processors import TakeFirst
from scrapy.loader import ItemLoader
from scrapy.item import Item, Field
import csv

class CommunityItem(Item):
    community_title = Field(output_processor=TakeFirst())
    post_title = Field(output_processor=TakeFirst())
    post_author = Field(output_processor=TakeFirst())
    post_date = Field(output_processor=TakeFirst())
    post_content = Field(output_processor=TakeFirst())

class CommunitySpider(scrapy.Spider):
    name = "community_spider"
    start_urls = ['https://cafedread.net/discover']  # Start URL

    def parse(self, response):
        # Discover communities
        communities = response.xpath('//div[contains(@class, "media")]//h5/a')
        for community in communities:
            community_title = community.xpath('.//text()').get()
            community_link = response.urljoin(community.xpath('.//@href').get())
            yield Request(community_link, callback=self.parse_posts, meta={'community_title': community_title})

        # Handle pagination
        next_page = response.xpath('//li[@class="page-item"]/a[@rel="next"]/@href').get()
        if next_page:
            yield response.follow(next_page, callback=self.parse)

    def parse_posts(self, response):
        community_title = response.meta['community_title']
        posts = response.xpath('//h5[contains(@class, "mb-2")]/a')
        for post in posts:
            post_link = response.urljoin(post.xpath('.//@href').get())
            post_title = post.xpath('.//text()').get()
            # Follow the post link to get further details
            yield Request(post_link, callback=self.parse_post_details, meta={
                'community_title': community_title,
                'post_title': post_title
            })

        # Handle pagination in posts
        next_page = response.xpath('//li[@class="page-item"]/a[@rel="next"]/@href').get()
        if next_page:
            yield response.follow(next_page, callback=self.parse_posts, meta={'community_title': community_title})

    def parse_post_details(self, response):
        loader = ItemLoader(item=CommunityItem(), response=response)
        loader.add_value('community_title', response.meta['community_title'])
        loader.add_value('post_title', response.meta['post_title'])
        loader.add_xpath('post_author', '//div[contains(@class, "card-body")]//p/a/text()')
        loader.add_xpath('post_date', '//div[contains(@class, "card-body")]//span/@title')
        loader.add_xpath('post_content', 'string(//div[contains(@class, "post-body")]/p)')
        yield loader.load_item()

class CsvPipeline:
    def open_spider(self, spider):
        self.file = open('community_posts_details.csv', 'w', newline='')
        self.writer = csv.writer(self.file)
        self.writer.writerow(['Community Title', 'Post Title', 'Post Author', 'Date/Time', 'Post Content'])

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        self.writer.writerow([item['community_title'], item['post_title'], item['post_author'], item['post_date'], item['post_content']])
        return item

if __name__ == "__main__":
    process = CrawlerProcess(settings={
        'ITEM_PIPELINES': {'__main__.CsvPipeline': 1},
    })
    process.crawl(CommunitySpider)
    process.start()
# Out:
# Streaming output truncated to the last 5000 lines.
# 2024-06-02 18:51:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/8f4f383b1d3f962e4796>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/drugman234',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tSaw this guy on Super Market, though he '
#                  "doesn't have much sale but got some good prices. He claims "
#                  'to be active on other markets, so I was wondering if someone '
#                  'in here can vouch for him that he is '
#                  'legit?                        ',
#  'post_date': '2024-01-26 08:44:00',
#  'post_title': 'can anyone vouch for vendor '
#                'venspyrou?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/e881e2c5f3f1ff1263fd> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# 2024-06-02 18:51:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/e881e2c5f3f1ff1263fd> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/e881e2c5f3f1ff1263fd>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/BroCast97',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tWant to buy Elvanse from him just checking if '
#                  "he's legit                        ",
#  'post_date': '2024-01-25 03:52:00',
#  'post_title': "Has anybody bought rc's from mangoosen "
#                'recently?                                    '}
# 2024-06-02 18:51:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/e881e2c5f3f1ff1263fd>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/BroCast97',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tWant to buy Elvanse from him just checking if '
#                  "he's legit                        ",
#  'post_date': '2024-01-25 03:52:00',
#  'post_title': "Has anybody bought rc's from mangoosen "
#                'recently?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/63a78ec5006e34836bc4> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# 2024-06-02 18:51:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/63a78ec5006e34836bc4> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/f8e99f25d6ca907cc5c5> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/f8e99f25d6ca907cc5c5> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/63a78ec5006e34836bc4>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SmokeyKiller20',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\they im looking for a bulk cocaine dealer eu im '
#                  'looking for 100g-1kg more later on\n'
#                  'im looking for amazing quality coke for cheap prices i know '
#                  'thats possible thats why im not looking for coke thats been '
#                  'trough 5 different hands if possible looking for people who '
#                  'import it straight from south america to spain netherlands '
#                  'germany belgium dont really care which country ofc ik '
#                  'netherlands is a higher risk country but as long as its in '
#                  'the european union im ok with it\n'
#                  'also best if you ship with private curiers: ups dhl dpd \n'
#                  'im from the baltics looking for a long buisness connection '
#                  'not one shipment and then get scammed on the second one\n'
#                  'also great stealth is a must again looking for long time '
#                  'connection not a scam or a ticket to '
#                  'jail                        ',
#  'post_date': '2024-01-24 18:12:00',
#  'post_title': 'LOOKING FOR BULK COCAINE DEALER '
#                'EU                                    '}
# 2024-06-02 18:51:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/63a78ec5006e34836bc4>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SmokeyKiller20',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\they im looking for a bulk cocaine dealer eu im '
#                  'looking for 100g-1kg more later on\n'
#                  'im looking for amazing quality coke for cheap prices i know '
#                  'thats possible thats why im not looking for coke thats been '
#                  'trough 5 different hands if possible looking for people who '
#                  'import it straight from south america to spain netherlands '
#                  'germany belgium dont really care which country ofc ik '
#                  'netherlands is a higher risk country but as long as its in '
#                  'the european union im ok with it\n'
#                  'also best if you ship with private curiers: ups dhl dpd \n'
#                  'im from the baltics looking for a long buisness connection '
#                  'not one shipment and then get scammed on the second one\n'
#                  'also great stealth is a must again looking for long time '
#                  'connection not a scam or a ticket to '
#                  'jail                        ',
#  'post_date': '2024-01-24 18:12:00',
#  'post_title': 'LOOKING FOR BULK COCAINE DEALER '
#                'EU                                    '}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/f8e99f25d6ca907cc5c5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/TheHabibi',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tI have looked all over the clear net and '
#                  'various markets and can not seem to find Norflurazepam '
#                  'powder or pills if any of you could point me in the right '
#                  "direction that would be greatly appreciated! I haven't been "
#                  'able to find it since Barstool disappeared and it was one of '
#                  'my favorites                        ',
#  'post_date': '2024-01-20 22:04:00',
#  'post_title': 'Norflurazepam                                    '}
# 2024-06-02 18:51:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/f8e99f25d6ca907cc5c5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/TheHabibi',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tI have looked all over the clear net and '
#                  'various markets and can not seem to find Norflurazepam '
#                  'powder or pills if any of you could point me in the right '
#                  "direction that would be greatly appreciated! I haven't been "
#                  'able to find it since Barstool disappeared and it was one of '
#                  'my favorites                        ',
#  'post_date': '2024-01-20 22:04:00',
#  'post_title': 'Norflurazepam                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/eda14ed5b9807253ea9d> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/eda14ed5b9807253ea9d> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/eda14ed5b9807253ea9d>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/jkbler',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHey so pretty straight forward, I know its not '
#                  "the most abundant of substances but I've developed a slight "
#                  'benzo habit and would like to taper off as safely and '
#                  'comfortably as possible. If anyone knows a vendor across any '
#                  'of the markets who sells flumazenil, please reach '
#                  'out                        ',
#  'post_date': '2024-01-20 13:41:00',
#  'post_title': 'Flumazenil US -> US?                                    '}
# 2024-06-02 18:51:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/eda14ed5b9807253ea9d>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/jkbler',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHey so pretty straight forward, I know its not '
#                  "the most abundant of substances but I've developed a slight "
#                  'benzo habit and would like to taper off as safely and '
#                  'comfortably as possible. If anyone knows a vendor across any '
#                  'of the markets who sells flumazenil, please reach '
#                  'out                        ',
#  'post_date': '2024-01-20 13:41:00',
#  'post_title': 'Flumazenil US -> US?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/73e81648609165fd3616> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# 2024-06-02 18:51:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/73e81648609165fd3616> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/73e81648609165fd3616>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/DegenerateBull51',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tDoes anybody know of any vendors that sell '
#                  "alcohol and ship it to the US, preferably from the US, can't "
#                  "find and on archetyp and couldn't find any on bohemia back "
#                  'when I was using that                        ',
#  'post_date': '2024-01-25 21:10:00',
#  'post_title': 'in need of Alcohol vendors US - '
#                'US                                    '}
# 2024-06-02 18:51:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/73e81648609165fd3616>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/DegenerateBull51',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tDoes anybody know of any vendors that sell '
#                  "alcohol and ship it to the US, preferably from the US, can't "
#                  "find and on archetyp and couldn't find any on bohemia back "
#                  'when I was using that                        ',
#  'post_date': '2024-01-25 21:10:00',
#  'post_title': 'in need of Alcohol vendors US - '
#                'US                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/79204cf1dc75de9e128e> (referer: https://cafedread.net/d/DNMSourcing?page=105)
# 2024-06-02 18:51:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/79204cf1dc75de9e128e> (referer: https://cafedread.net/d/DNMSourcing?page=105)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/79204cf1dc75de9e128e>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/ByAnyMeans101',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tthe best quality vendor for bulk in blues (oxy '
#                  '30) can be pressed                        ',
#  'post_date': '2024-01-31 04:13:00',
#  'post_title': 'blues - oxy 30s                                    '}
# 2024-06-02 18:51:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/79204cf1dc75de9e128e>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/ByAnyMeans101',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tthe best quality vendor for bulk in blues (oxy '
#                  '30) can be pressed                        ',
#  'post_date': '2024-01-31 04:13:00',
#  'post_title': 'blues - oxy 30s                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/27808c46ad9357b8d8df> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# 2024-06-02 18:51:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/27808c46ad9357b8d8df> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/27808c46ad9357b8d8df>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Deadlinepassed',
#  'post_content': '\n'
#                  "\t\t\t\t\t\t\tSo I didn't hear about Cypher or Dark Matter "
#                  "from the last time I was here and haven't read much about "
#                  'Dark Matter here on Dread. Thoughts?                        ',
#  'post_date': '2024-01-24 00:06:00',
#  'post_title': 'Dark Matter, Cypher. Abacus (sort of) '
#                '?                                    '}
# 2024-06-02 18:51:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/27808c46ad9357b8d8df>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Deadlinepassed',
#  'post_content': '\n'
#                  "\t\t\t\t\t\t\tSo I didn't hear about Cypher or Dark Matter "
#                  "from the last time I was here and haven't read much about "
#                  'Dark Matter here on Dread. Thoughts?                        ',
#  'post_date': '2024-01-24 00:06:00',
#  'post_title': 'Dark Matter, Cypher. Abacus (sort of) '
#                '?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/4c54e3de2f701500af57> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/4c54e3de2f701500af57> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/4c54e3de2f701500af57>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/i-cloud-9',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\teyelovelucy used to be on asap market... not '
#                  "sure where they went once that shut down. Haven't been able "
#                  'to find them on any of the main daunt market links...\n'
#                  '\n'
#                  'Thanks!                        ',
#  'post_date': '2024-01-19 06:01:00',
#  'post_title': 'looking for eyelovelucy...                                    '}
# 2024-06-02 18:51:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/4c54e3de2f701500af57>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/i-cloud-9',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\teyelovelucy used to be on asap market... not '
#                  "sure where they went once that shut down. Haven't been able "
#                  'to find them on any of the main daunt market links...\n'
#                  '\n'
#                  'Thanks!                        ',
#  'post_date': '2024-01-19 06:01:00',
#  'post_title': 'looking for eyelovelucy...                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/854637bcbfc90fb2b4c5> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/854637bcbfc90fb2b4c5> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/0dabfd7606684047bddb> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# 2024-06-02 18:51:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/0dabfd7606684047bddb> (referer: https://cafedread.net/d/DNMSourcing?page=104)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/4615ad880e5c158fbb41> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/4615ad880e5c158fbb41> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/854637bcbfc90fb2b4c5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/kittenmonster',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHi, can anyone recommend me a good market for '
#                  'buying oxy or similar that has vendors shipping to '
#                  'spain?                        ',
#  'post_date': '2024-01-19 15:39:00',
#  'post_title': 'Looking for good market for buying oxy which ships to '
#                'spain                                    '}
# 2024-06-02 18:51:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/854637bcbfc90fb2b4c5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/kittenmonster',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHi, can anyone recommend me a good market for '
#                  'buying oxy or similar that has vendors shipping to '
#                  'spain?                        ',
#  'post_date': '2024-01-19 15:39:00',
#  'post_title': 'Looking for good market for buying oxy which ships to '
#                'spain                                    '}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/0dabfd7606684047bddb>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Skelets04',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tJst like the title looking for trusted '
#                  'vendors\n'
#                  'Who can ship primary to Norway and or Latvia "EU" county\n'
#                  'main things i am looking for is drugs lol\n'
#                  'thanks in advanced                        ',
#  'post_date': '2024-01-23 22:22:00',
#  'post_title': 'Looking for Vendors                                    '}
# 2024-06-02 18:51:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/0dabfd7606684047bddb>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Skelets04',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tJst like the title looking for trusted '
#                  'vendors\n'
#                  'Who can ship primary to Norway and or Latvia "EU" county\n'
#                  'main things i am looking for is drugs lol\n'
#                  'thanks in advanced                        ',
#  'post_date': '2024-01-23 22:22:00',
#  'post_title': 'Looking for Vendors                                    '}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/4615ad880e5c158fbb41>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/darwin1859',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tDoes anyone know a seller\n'
#                  'methylphenidate or modafinil for France?\n'
#                  'ideally only national (France to France)\n'
#                  'thank you very much for the answers                        ',
#  'post_date': '2024-02-10 18:03:00',
#  'post_title': 'looking for methylphenidate or modafinil '
#                '(france)                                    '}
# 2024-06-02 18:51:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/4615ad880e5c158fbb41>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/darwin1859',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tDoes anyone know a seller\n'
#                  'methylphenidate or modafinil for France?\n'
#                  'ideally only national (France to France)\n'
#                  'thank you very much for the answers                        ',
#  'post_date': '2024-02-10 18:03:00',
#  'post_title': 'looking for methylphenidate or modafinil '
#                '(france)                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/e8693653ba0ba56cf473> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/e8693653ba0ba56cf473> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/e8693653ba0ba56cf473>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SOAP_MACTAVISH',
#  'post_content': '\n'
#                  "\t\t\t\t\t\t\tI am looking to source any dnm's or vendors "
#                  'who ship premium quality Concentrates such as shatter or '
#                  'live resin or carts shipped to UK                        ',
#  'post_date': '2024-01-19 18:24:00',
#  'post_title': 'HIGH GRADE CONCENTRATES / CARTS SHIPPED TO '
#                'UK                                    '}
# 2024-06-02 18:51:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/e8693653ba0ba56cf473>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SOAP_MACTAVISH',
#  'post_content': '\n'
#                  "\t\t\t\t\t\t\tI am looking to source any dnm's or vendors "
#                  'who ship premium quality Concentrates such as shatter or '
#                  'live resin or carts shipped to UK                        ',
#  'post_date': '2024-01-19 18:24:00',
#  'post_title': 'HIGH GRADE CONCENTRATES / CARTS SHIPPED TO '
#                'UK                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/21d53b120c62cf379914> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/21d53b120c62cf379914> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/21d53b120c62cf379914>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/qsd211',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking for anyone who ships MDA to the UK. '
#                  'First pill I ever took was MDA years ago thinking it was a '
#                  'normal xtc pill. Been searching through every market and '
#                  'have had no luck unfortunately. Any suggestions of legit '
#                  'vendors would be appreciated since it seems that its very '
#                  'hard to source over here.                        ',
#  'post_date': '2024-02-09 18:09:00',
#  'post_title': 'MDA to UK                                    '}
# 2024-06-02 18:51:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/21d53b120c62cf379914>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/qsd211',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking for anyone who ships MDA to the UK. '
#                  'First pill I ever took was MDA years ago thinking it was a '
#                  'normal xtc pill. Been searching through every market and '
#                  'have had no luck unfortunately. Any suggestions of legit '
#                  'vendors would be appreciated since it seems that its very '
#                  'hard to source over here.                        ',
#  'post_date': '2024-02-09 18:09:00',
#  'post_title': 'MDA to UK                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/c862966de2f6457563f5> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/c862966de2f6457563f5> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/c862966de2f6457563f5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/cjc123',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tCan someone please recommend an established '
#                  'vendor that ships from France?\n'
#                  '\n'
#                  'Small quantities and domestic only '
#                  'please.                        ',
#  'post_date': '2024-02-10 17:29:00',
#  'post_title': 'MDMA and coke , France to '
#                'France.                                    '}
# 2024-06-02 18:51:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/c862966de2f6457563f5>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/cjc123',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tCan someone please recommend an established '
#                  'vendor that ships from France?\n'
#                  '\n'
#                  'Small quantities and domestic only '
#                  'please.                        ',
#  'post_date': '2024-02-10 17:29:00',
#  'post_title': 'MDMA and coke , France to '
#                'France.                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/883f3866bcb3ee2926b1> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/883f3866bcb3ee2926b1> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/883f3866bcb3ee2926b1>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Bagdan420',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tAlso looking for balaclavas and other '
#                  'masks.                        ',
#  'post_date': '2024-02-10 12:02:00',
#  'post_title': 'Looking for vendor that sells replica clothing, mainly '
#                'streetwear and '
#                'accessories.                                    '}
# 2024-06-02 18:51:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/883f3866bcb3ee2926b1>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Bagdan420',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tAlso looking for balaclavas and other '
#                  'masks.                        ',
#  'post_date': '2024-02-10 12:02:00',
#  'post_title': 'Looking for vendor that sells replica clothing, mainly '
#                'streetwear and '
#                'accessories.                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/397da2f1a35711917e50> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/397da2f1a35711917e50> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/397da2f1a35711917e50>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/NeedhelpHUGEPOTENTIALGAIN',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIs this even possible, i have encountered too '
#                  'many blatant scammers in my clearnet search of suppliers, '
#                  'chinese people using videos from the golden days to persuade '
#                  'people into sending them money and have a massive deal lined '
#                  'up if i can find it, if anyone knows a source with '
#                  'reasonable bulk pricing, please notify me, i read about some '
#                  'production in balkan countries, the prcs, but website wont '
#                  'load and cant even find it now. If anyone within europe has '
#                  'any of these chems, we can do business and make huge gains '
#                  'and ROI                        ',
#  'post_date': '2024-02-09 12:04:00',
#  'post_title': 'I have to find 5cladba, 6cladba or jwh 210 within europe at a '
#                'reasonable price                                    '}
# 2024-06-02 18:51:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/397da2f1a35711917e50>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/NeedhelpHUGEPOTENTIALGAIN',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIs this even possible, i have encountered too '
#                  'many blatant scammers in my clearnet search of suppliers, '
#                  'chinese people using videos from the golden days to persuade '
#                  'people into sending them money and have a massive deal lined '
#                  'up if i can find it, if anyone knows a source with '
#                  'reasonable bulk pricing, please notify me, i read about some '
#                  'production in balkan countries, the prcs, but website wont '
#                  'load and cant even find it now. If anyone within europe has '
#                  'any of these chems, we can do business and make huge gains '
#                  'and ROI                        ',
#  'post_date': '2024-02-09 12:04:00',
#  'post_title': 'I have to find 5cladba, 6cladba or jwh 210 within europe at a '
#                'reasonable price                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/019a1b0ad469850d9180> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/019a1b0ad469850d9180> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/019a1b0ad469850d9180>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/noobinips',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tlooking for vendors that ship to the states '
#                  'that has good standing dnm account and at minimum of 50% '
#                  'reship if customs grabs the pack theres a huge market hole '
#                  'here that needs to be filled which means more money to be '
#                  'made some examples 3mmc, 4mmc, 4acodmt, 5meodmt, pharmacy '
#                  'opioids,ephedrine meth, amphetamine sulfate, xanax and so '
#                  'much more comment your market name and where i can find '
#                  'you                        ',
#  'post_date': '2024-02-10 05:04:00',
#  'post_title': 'international to the '
#                'states                                    '}
# 2024-06-02 18:51:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/019a1b0ad469850d9180>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/noobinips',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tlooking for vendors that ship to the states '
#                  'that has good standing dnm account and at minimum of 50% '
#                  'reship if customs grabs the pack theres a huge market hole '
#                  'here that needs to be filled which means more money to be '
#                  'made some examples 3mmc, 4mmc, 4acodmt, 5meodmt, pharmacy '
#                  'opioids,ephedrine meth, amphetamine sulfate, xanax and so '
#                  'much more comment your market name and where i can find '
#                  'you                        ',
#  'post_date': '2024-02-10 05:04:00',
#  'post_title': 'international to the '
#                'states                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/a68ecc4ae2b838b78a73> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/a68ecc4ae2b838b78a73> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/a68ecc4ae2b838b78a73>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/dagwoodrobin',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking for a vendor that sells Xanax or other '
#                  'Benzos domestically in Belgium (from Belgium to Belgium). '
#                  'found only etizolam on abacus, anyone know a good vendor? '
#                  "Doesn't have to be pharma-grade, RC's are also "
#                  'OK                        ',
#  'post_date': '2024-02-08 13:28:00',
#  'post_title': 'Benzos to Belgium                                    '}
# 2024-06-02 18:51:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/a68ecc4ae2b838b78a73>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/dagwoodrobin',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking for a vendor that sells Xanax or other '
#                  'Benzos domestically in Belgium (from Belgium to Belgium). '
#                  'found only etizolam on abacus, anyone know a good vendor? '
#                  "Doesn't have to be pharma-grade, RC's are also "
#                  'OK                        ',
#  'post_date': '2024-02-08 13:28:00',
#  'post_title': 'Benzos to Belgium                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/12c57a37c0e789655260> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/12c57a37c0e789655260> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/7539e5d1bf624cd86276> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/7539e5d1bf624cd86276> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/12c57a37c0e789655260>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SnookerBlueGhost',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHave tried partyfaves, roadrunna,  '
#                  'weareamsterdam, das apothecary, and nothing has even been '
#                  'week ghb/gbl/bdo. \n'
#                  '\n'
#                  'Any recommendations (for Vancouver if it '
#                  'matters)                        ',
#  'post_date': '2024-02-08 07:57:00',
#  'post_title': 'ghb in Canada?                                    '}
# 2024-06-02 18:51:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/12c57a37c0e789655260>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/SnookerBlueGhost',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHave tried partyfaves, roadrunna,  '
#                  'weareamsterdam, das apothecary, and nothing has even been '
#                  'week ghb/gbl/bdo. \n'
#                  '\n'
#                  'Any recommendations (for Vancouver if it '
#                  'matters)                        ',
#  'post_date': '2024-02-08 07:57:00',
#  'post_title': 'ghb in Canada?                                    '}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/7539e5d1bf624cd86276>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Jammydodger1234',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIam looking a review of a solid vendor that '
#                  'sends this out? AKA synthetic shrooms (4-ACO-DMT)\n'
#                  '\n'
#                  'Regards                        ',
#  'post_date': '2024-02-08 14:19:00',
#  'post_title': '4-ACO-DMT vendor                                    '}
# 2024-06-02 18:51:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/7539e5d1bf624cd86276>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/Jammydodger1234',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIam looking a review of a solid vendor that '
#                  'sends this out? AKA synthetic shrooms (4-ACO-DMT)\n'
#                  '\n'
#                  'Regards                        ',
#  'post_date': '2024-02-08 14:19:00',
#  'post_title': '4-ACO-DMT vendor                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/4156037fba247b468e2d> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# 2024-06-02 18:51:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/4156037fba247b468e2d> (referer: https://cafedread.net/d/DNMSourcing?page=103)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/b87a24c3fd03c9e484be> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/b87a24c3fd03c9e484be> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/4156037fba247b468e2d>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/randomperson4',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\thave a few BDO vendors im looking at on '
#                  'incognito, dont know if BDO is worse or what the difference '
#                  'is to GHB                        ',
#  'post_date': '2024-01-20 05:09:00',
#  'post_title': 'looking for a US domestic GHB vendor (that preferrably doesnt '
#                'break the bank)                                    '}
# 2024-06-02 18:51:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/4156037fba247b468e2d>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/randomperson4',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\thave a few BDO vendors im looking at on '
#                  'incognito, dont know if BDO is worse or what the difference '
#                  'is to GHB                        ',
#  'post_date': '2024-01-20 05:09:00',
#  'post_title': 'looking for a US domestic GHB vendor (that preferrably doesnt '
#                'break the bank)                                    '}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/b87a24c3fd03c9e484be>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/ionodolt42',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking to buy etizolam domestically in pill '
#                  'form, not powder. Anyone know any good '
#                  'places/vendors?                        ',
#  'post_date': '2024-02-08 02:16:00',
#  'post_title': 'Good US-US etizolam pills '
#                'venders?                                    '}
# 2024-06-02 18:51:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/b87a24c3fd03c9e484be>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/ionodolt42',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tLooking to buy etizolam domestically in pill '
#                  'form, not powder. Anyone know any good '
#                  'places/vendors?                        ',
#  'post_date': '2024-02-08 02:16:00',
#  'post_title': 'Good US-US etizolam pills '
#                'venders?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/e138d63c0436bddc8017> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/e138d63c0436bddc8017> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/e138d63c0436bddc8017>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/jinxthecat',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHi, is Wakikiweedshop legit and running, i '
#                  'cant figure it out.. He hasnt posted in a long time but '
#                  'still active on arch.                        ',
#  'post_date': '2024-02-07 23:20:00',
#  'post_title': 'Wakikiweedshop alive?                                    '}
# 2024-06-02 18:51:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/e138d63c0436bddc8017>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/jinxthecat',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tHi, is Wakikiweedshop legit and running, i '
#                  'cant figure it out.. He hasnt posted in a long time but '
#                  'still active on arch.                        ',
#  'post_date': '2024-02-07 23:20:00',
#  'post_title': 'Wakikiweedshop alive?                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/31a2a6a3d571773eb5c6> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/31a2a6a3d571773eb5c6> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/31a2a6a3d571773eb5c6>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/exoticpilot',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tNeed USA XTC vendor with decoy '
#                  'packaging!                        ',
#  'post_date': '2024-02-08 16:28:00',
#  'post_title': 'Need USA XTC vendor with decoy '
#                'packaging!                                    '}
# 2024-06-02 18:51:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/31a2a6a3d571773eb5c6>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/exoticpilot',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tNeed USA XTC vendor with decoy '
#                  'packaging!                        ',
#  'post_date': '2024-02-08 16:28:00',
#  'post_title': 'Need USA XTC vendor with decoy '
#                'packaging!                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/334da27e62bcadc6b316> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/334da27e62bcadc6b316> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/334da27e62bcadc6b316>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/heroin4life',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tnot looking for sryup                        ',
#  'post_date': '2024-02-07 22:13:00',
#  'post_title': 'Looking for cad-cad morphine or codeine '
#                'pills                                    '}
# 2024-06-02 18:51:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/334da27e62bcadc6b316>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/heroin4life',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tnot looking for sryup                        ',
#  'post_date': '2024-02-07 22:13:00',
#  'post_title': 'Looking for cad-cad morphine or codeine '
#                'pills                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/90b69a5020b56cefbdd7> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/90b69a5020b56cefbdd7> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/90b69a5020b56cefbdd7>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/smaqhead',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\ti need a vendor to supply me with some uk mids '
#                  'im gonna be ordering between 1 and 4 ounces at a time any '
#                  'suggestions?                        ',
#  'post_date': '2024-02-07 09:23:00',
#  'post_title': 'looking for uk-uk weed '
#                'vendor                                    '}
# 2024-06-02 18:51:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/90b69a5020b56cefbdd7>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/smaqhead',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\ti need a vendor to supply me with some uk mids '
#                  'im gonna be ordering between 1 and 4 ounces at a time any '
#                  'suggestions?                        ',
#  'post_date': '2024-02-07 09:23:00',
#  'post_title': 'looking for uk-uk weed '
#                'vendor                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/ae04a0256769602a992a> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/ae04a0256769602a992a> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/ae04a0256769602a992a>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/wetemup',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tBeen looking on Arch but cant find shit for '
#                  'value unless if i need to just dick it and buy overseas, i '
#                  'dont wanna nor do i wanna buy from someone without a '
#                  'reputation but i cant find anything.. much love to all who '
#                  'help\n'
#                  '\n'
#                  '\n'
#                  'edit:\n'
#                  'idgaf if its not legitimate lean as long as the bottles are '
#                  'solid and theres no fent\n'
#                  'edit2: also i dont want my addy fried from international '
#                  'shipping                        ',
#  'post_date': '2024-02-07 07:40:00',
#  'post_title': 'Looking for sealed bottles of Lean preferably '
#                'US-US                                    '}
# 2024-06-02 18:51:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/ae04a0256769602a992a>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/wetemup',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tBeen looking on Arch but cant find shit for '
#                  'value unless if i need to just dick it and buy overseas, i '
#                  'dont wanna nor do i wanna buy from someone without a '
#                  'reputation but i cant find anything.. much love to all who '
#                  'help\n'
#                  '\n'
#                  '\n'
#                  'edit:\n'
#                  'idgaf if its not legitimate lean as long as the bottles are '
#                  'solid and theres no fent\n'
#                  'edit2: also i dont want my addy fried from international '
#                  'shipping                        ',
#  'post_date': '2024-02-07 07:40:00',
#  'post_title': 'Looking for sealed bottles of Lean preferably '
#                'US-US                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/5ee64ef7fcccc1195021> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/5ee64ef7fcccc1195021> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/5ee64ef7fcccc1195021>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/lilgotit',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIm in the market for a good K2 synthenic '
#                  'cannabiniod vendor based in the US. Someone with good '
#                  'stealth and head banging quality that will leave  people '
#                  'stuck for hours haha! No but seriously I want to be able to '
#                  'take care of those who are locked up escape reality for '
#                  'awhile.\n'
#                  '\n'
#                  'Preferably powder or liquid form. Thanks for the help '
#                  'guys!                        ',
#  'post_date': '2024-02-06 21:38:00',
#  'post_title': 'K2 Spice Synthetic Cannabiniod Vendor?? HEAD BANGNIG '
#                'QUALITY!!!                                    '}
# 2024-06-02 18:51:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/5ee64ef7fcccc1195021>
# {'community_title': '/d/DNMSourcing',
#  'post_author': '/u/lilgotit',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIm in the market for a good K2 synthenic '
#                  'cannabiniod vendor based in the US. Someone with good '
#                  'stealth and head banging quality that will leave  people '
#                  'stuck for hours haha! No but seriously I want to be able to '
#                  'take care of those who are locked up escape reality for '
#                  'awhile.\n'
#                  '\n'
#                  'Preferably powder or liquid form. Thanks for the help '
#                  'guys!                        ',
#  'post_date': '2024-02-06 21:38:00',
#  'post_title': 'K2 Spice Synthetic Cannabiniod Vendor?? HEAD BANGNIG '
#                'QUALITY!!!                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/d/DNMSourcing?page=107> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# 2024-06-02 18:51:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/d/DNMSourcing?page=107> (referer: https://cafedread.net/d/DNMSourcing?page=106)
# ...
#  'post_author': '/u/HugBunter',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tUnfortunately, I can 100% confirm the exit '
#                  'scam now.\n'
#                  '\n'
#                  'It is well known that Incognito purchased DarkNetLive and '
#                  'previously I have mentioned to Pharoah that if and when he '
#                  'decides to shut down, it would be great if he could hand '
#                  "over the domain in the process to ensure it isn't used "
#                  "maliciously. I've been talking to him back and fourth the "
#                  'past few hours and got to the point where I told him a '
#                  'warning is going live, to which his response was to try and '
#                  'bribe me to take Dread down or wipe all posts regarding '
#                  'Incognito, in return he will hand over DNL. Big mistake, he '
#                  "of all people should know I can't be bought and I won't "
#                  'hesitate to confirm the exit.\n'
#                  '\n'
#                  '/u/DarkDotFail /u/TorDotTaxi\n'
#                  '\n'
#                  'It would have been good for everyone if DNL could have been '
#                  'passed into good hands and my warning here will not make any '
#                  'difference to funds already lost to Incognito, but hopefully '
#                  'this will be enough now to try and ensure users stay clear '
#                  'and avoid losing more.\n'
#                  '\n',
#  'post_date': '2024-03-05 12:10:00',
#  'post_title': 'Incognito 100% Exit Scam - AVOID '
#                'NOW                                    '}
# 2024-06-02 18:57:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/43d121e0efd6060bb6e8>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/HugBunter',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tUnfortunately, I can 100% confirm the exit '
#                  'scam now.\n'
#                  '\n'
#                  'It is well known that Incognito purchased DarkNetLive and '
#                  'previously I have mentioned to Pharoah that if and when he '
#                  'decides to shut down, it would be great if he could hand '
#                  "over the domain in the process to ensure it isn't used "
#                  "maliciously. I've been talking to him back and fourth the "
#                  'past few hours and got to the point where I told him a '
#                  'warning is going live, to which his response was to try and '
#                  'bribe me to take Dread down or wipe all posts regarding '
#                  'Incognito, in return he will hand over DNL. Big mistake, he '
#                  "of all people should know I can't be bought and I won't "
#                  'hesitate to confirm the exit.\n'
#                  '\n'
#                  '/u/DarkDotFail /u/TorDotTaxi\n'
#                  '\n'
#                  'It would have been good for everyone if DNL could have been '
#                  'passed into good hands and my warning here will not make any '
#                  'difference to funds already lost to Incognito, but hopefully '
#                  'this will be enough now to try and ensure users stay clear '
#                  'and avoid losing more.\n'
#                  '\n',
#  'post_date': '2024-03-05 12:10:00',
#  'post_title': 'Incognito 100% Exit Scam - AVOID '
#                'NOW                                    '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/ec87abf4ded1a0495e0c> (referer: https://cafedread.net/d/DarkNetMarkets?page=29)
# 2024-06-02 18:57:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/ec87abf4ded1a0495e0c> (referer: https://cafedread.net/d/DarkNetMarkets?page=29)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/ec87abf4ded1a0495e0c>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/Francis_Nemesis',
#  'post_content': '\n\t\t\t\t\t\t\t[removed]                        ',
#  'post_date': '20th March, 2024 21:24',
#  'post_title': 'Nemesis Market Got Seized                             '}
# 2024-06-02 18:57:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/ec87abf4ded1a0495e0c>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/Francis_Nemesis',
#  'post_content': '\n\t\t\t\t\t\t\t[removed]                        ',
#  'post_date': '20th March, 2024 21:24',
#  'post_title': 'Nemesis Market Got Seized                             '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/b71ba42f34e1125e31e2> (referer: https://cafedread.net/d/DarkNetMarkets?page=15)
# 2024-06-02 18:57:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/b71ba42f34e1125e31e2> (referer: https://cafedread.net/d/DarkNetMarkets?page=15)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/b71ba42f34e1125e31e2>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/PitViper',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIt seems no one is aware he is banned from TMG '
#                  'for either being compromised, possible LEO, and sloppy '
#                  'opsec/stealth. Apparently such blatant disregard in stealth, '
#                  'his customers got jammed up. TeamTrust was just reinsated '
#                  'the last few month a BAN! And now trust-in-us is MIA, and '
#                  "trust members keep saying its no big deal, they're sure "
#                  "it'll all get figured out. Sounds shady af to me. Oh and "
#                  'Trust has a bizarre $100/100 tab sale.\n'
#                  " and he's nowhere to be found so and Teamtrust member "
#                  'suddenly has a sheet up for $125. Profile description '
#                  'identical to trust. Like the shipping every tues/fri thing. '
#                  'Can anyone enlighten me on the status of team trust and '
#                  'should we stear clear?                        ',
#  'post_date': '27th August, 2018 14:37',
#  'post_title': 'Is Pelican actually LEO or just being '
#                'investiagted                                                             '}
# 2024-06-02 18:57:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/b71ba42f34e1125e31e2>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/PitViper',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tIt seems no one is aware he is banned from TMG '
#                  'for either being compromised, possible LEO, and sloppy '
#                  'opsec/stealth. Apparently such blatant disregard in stealth, '
#                  'his customers got jammed up. TeamTrust was just reinsated '
#                  'the last few month a BAN! And now trust-in-us is MIA, and '
#                  "trust members keep saying its no big deal, they're sure "
#                  "it'll all get figured out. Sounds shady af to me. Oh and "
#                  'Trust has a bizarre $100/100 tab sale.\n'
#                  " and he's nowhere to be found so and Teamtrust member "
#                  'suddenly has a sheet up for $125. Profile description '
#                  'identical to trust. Like the shipping every tues/fri thing. '
#                  'Can anyone enlighten me on the status of team trust and '
#                  'should we stear clear?                        ',
#  'post_date': '27th August, 2018 14:37',
#  'post_title': 'Is Pelican actually LEO or just being '
#                'investiagted                                                             '}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://cafedread.net/post/9f72bcecd8526a044518> (referer: https://cafedread.net/d/DarkNetMarkets?page=23)
# 2024-06-02 18:57:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://cafedread.net/post/9f72bcecd8526a044518> (referer: https://cafedread.net/d/DarkNetMarkets?page=23)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://cafedread.net/post/9f72bcecd8526a044518>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/Preview-Of-Freedom',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tsince my return from the wsm fall out i have '
#                  'applied to cryptonia, berlusconi, tochka and empire. i have '
#                  'been vending since sr1 and have a very large amount of '
#                  'verified sales and large volume. \n'
#                  '\n'
#                  'none of the previously mentioned markets are willing to '
#                  'waive vendor bond and none of them are able to verify any '
#                  'past vending legacy unless it is currently active. since '
#                  'when did this become the norm???? \n'
#                  '\n'
#                  'it is amateur hour for the dnm scene. are these markets ran '
#                  'by script kiddies biding time until the internal market '
#                  'wallets grow fat enough to exit scam as we have all seen '
#                  'play out time and time again???? where are the real hackers '
#                  'that used to run the show???? where are the real business '
#                  'gods????\n'
#                  '\n'
#                  'if the markets are run by amateurs driven by the future '
#                  'hopes of stealing money from honest goods traders then this '
#                  'scene is doomed. when will the real pros return????\n'
#                  '\n'
#                  'best wishes\n'
#                  'PoF                        ',
#  'post_date': '12th August, 2019 07:18',
#  'post_title': 'Looking for a trusted market place to vend on that is not ran '
#                'by '
#                'amateurs.                                                             '}
# 2024-06-02 18:57:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://cafedread.net/post/9f72bcecd8526a044518>
# {'community_title': '/d/DarkNetMarkets',
#  'post_author': '/u/Preview-Of-Freedom',
#  'post_content': '\n'
#                  '\t\t\t\t\t\t\tsince my return from the wsm fall out i have '
#                  'applied to cryptonia, berlusconi, tochka and empire. i have '
#                  'been vending since sr1 and have a very large amount of '
#                  'verified sales and large volume. \n'
#                  '\n'
#                  'none of the previously mentioned markets are willing to '
#                  'waive vendor bond and none of them are able to verify any '
#                  'past vending legacy unless it is currently active. since '
#                  'when did this become the norm???? \n'
#                  '\n'
#                  'it is amateur hour for the dnm scene. are these markets ran '
#                  'by script kiddies biding time until the internal market '
#                  'wallets grow fat enough to exit scam as we have all seen '
#                  'play out time and time again???? where are the real hackers '
#                  'that used to run the show???? where are the real business '
#                  'gods????\n'
#                  '\n'
#                  'if the markets are run by amateurs driven by the future '
#                  'hopes of stealing money from honest goods traders then this '
#                  'scene is doomed. when will the real pros return????\n'
#                  '\n'
#                  'best wishes\n'
#                  'PoF                        ',
#  'post_date': '12th August, 2019 07:18',
#  'post_title': 'Looking for a trusted market place to vend on that is not ran '
#                'by '
#                'amateurs.                                                             '}
# ERROR:scrapy.downloadermiddlewares.retry:Gave up retrying <GET https://cafedread.net/post/09c5535d05db7298a3f9> (failed 3 times): 524 Unknown Status
# 2024-06-02 18:57:38 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://cafedread.net/post/09c5535d05db7298a3f9> (failed 3 times): 524 Unknown Status
# DEBUG:scrapy.core.engine:Crawled (524) <GET https://cafedread.net/post/09c5535d05db7298a3f9> (referer: https://cafedread.net/d/DarkNetMarkets?page=54)
# 2024-06-02 18:57:38 [scrapy.core.engine] DEBUG: Crawled (524) <GET https://cafedread.net/post/09c5535d05db7298a3f9> (referer: https://cafedread.net/d/DarkNetMarkets?page=54)
# INFO:scrapy.spidermiddlewares.httperror:Ignoring response <524 https://cafedread.net/post/09c5535d05db7298a3f9>: HTTP status code is not handled or not allowed
# 2024-06-02 18:57:38 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <524 https://cafedread.net/post/09c5535d05db7298a3f9>: HTTP status code is not handled or not allowed
# INFO:scrapy.core.engine:Closing spider (finished)
# 2024-06-02 18:57:38 [scrapy.core.engine] INFO: Closing spider (finished)
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 25084707,
#  'downloader/request_count': 24769,
#  'downloader/request_method_count/GET': 24769,
#  'downloader/response_bytes': 215952316,
#  'downloader/response_count': 24769,
#  'downloader/response_status_count/200': 24587,
#  'downloader/response_status_count/500': 105,
#  'downloader/response_status_count/502': 1,
#  'downloader/response_status_count/520': 14,
#  'downloader/response_status_count/524': 62,
#  'dupefilter/filtered': 2568,
#  'elapsed_time_seconds': 31877.844661,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 6, 2, 18, 57, 38, 128850, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 429519542,
#  'httpcompression/response_count': 24587,
#  'httperror/response_ignored_count': 62,
#  'httperror/response_ignored_status_count/500': 35,
#  'httperror/response_ignored_status_count/520': 14,
#  'httperror/response_ignored_status_count/524': 13,
#  'item_scraped_count': 22982,
#  'log_count/DEBUG': 47755,
#  'log_count/ERROR': 64,
#  'log_count/INFO': 603,
#  'memusage/max': 177258496,
#  'memusage/startup': 135192576,
#  'request_depth_max': 125,
#  'response_received_count': 24649,
#  'retry/count': 120,
#  'retry/max_reached': 48,
#  'retry/reason_count/500 Internal Server Error': 70,
#  'retry/reason_count/502 Bad Gateway': 1,
#  'retry/reason_count/524 Unknown Status': 49,
#  'scheduler/dequeued': 24769,
#  'scheduler/dequeued/memory': 24769,
#  'scheduler/enqueued': 24769,
#  'scheduler/enqueued/memory': 24769,
#  'start_time': datetime.datetime(2024, 6, 2, 10, 6, 20, 284189, tzinfo=datetime.timezone.utc)}
# 2024-06-02 18:57:38 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 25084707,
#  'downloader/request_count': 24769,
#  'downloader/request_method_count/GET': 24769,
#  'downloader/response_bytes': 215952316,
#  'downloader/response_count': 24769,
#  'downloader/response_status_count/200': 24587,
#  'downloader/response_status_count/500': 105,
#  'downloader/response_status_count/502': 1,
#  'downloader/response_status_count/520': 14,
#  'downloader/response_status_count/524': 62,
#  'dupefilter/filtered': 2568,
#  'elapsed_time_seconds': 31877.844661,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 6, 2, 18, 57, 38, 128850, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 429519542,
#  'httpcompression/response_count': 24587,
#  'httperror/response_ignored_count': 62,
#  'httperror/response_ignored_status_count/500': 35,
#  'httperror/response_ignored_status_count/520': 14,
#  'httperror/response_ignored_status_count/524': 13,
#  'item_scraped_count': 22982,
#  'log_count/DEBUG': 47755,
#  'log_count/ERROR': 64,
#  'log_count/INFO': 603,
#  'memusage/max': 177258496,
#  'memusage/startup': 135192576,
#  'request_depth_max': 125,
#  'response_received_count': 24649,
#  'retry/count': 120,
#  'retry/max_reached': 48,
#  'retry/reason_count/500 Internal Server Error': 70,
#  'retry/reason_count/502 Bad Gateway': 1,
#  'retry/reason_count/524 Unknown Status': 49,
#  'scheduler/dequeued': 24769,
#  'scheduler/dequeued/memory': 24769,
#  'scheduler/enqueued': 24769,
#  'scheduler/enqueued/memory': 24769,
#  'start_time': datetime.datetime(2024, 6, 2, 10, 6, 20, 284189, tzinfo=datetime.timezone.utc)}
# INFO:scrapy.core.engine:Spider closed (finished)
# 2024-06-02 18:57:38 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.read_csv('community_posts_details.csv')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2024-06-02 18:57:38 [numexpr.utils] INFO: NumExpr defaulting to 2 threads.

# %%
community_posts_details.to_csv('community_posts_details.csv', index=False)

# %%
df.tail()
# Out:
#          Community Title                                         Post Title  \
# 22977  /d/DarkNetMarkets  DrLysergic report thread                      ...
# 22978  /d/DarkNetMarkets  Incognito 100% Exit Scam - AVOID NOW          ...
# 22979  /d/DarkNetMarkets  Nemesis Market Got Seized                     ...
# 22980  /d/DarkNetMarkets  Is Pelican actually LEO or just being investia...
# 22981  /d/DarkNetMarkets  Looking for a trusted market place to vend on ...
#
#                  Post Author                Date/Time  \
# 22977           /u/HugBunter   22nd March, 2019 12:50
# 22978           /u/HugBunter      2024-03-05 12:10:00
# 22979     /u/Francis_Nemesis   20th March, 2024 21:24
# 22980            /u/PitViper  27th August, 2018 14:37
# 22981  /u/Preview-Of-Freedom  12th August, 2019 07:18
#
#                                             Post Content
# 22977  \n\t\t\t\t\t\t\tHi,\n\nThere have been a tonne...
# 22978  \n\t\t\t\t\t\t\tUnfortunately, I can 100% conf...
# 22979  \n\t\t\t\t\t\t\t[removed]
# 22980  \n\t\t\t\t\t\t\tIt seems no one is aware he is...
# 22981  \n\t\t\t\t\t\t\tsince my return from the wsm f...

# %%
df.shape
# Out:
# (22982, 5)
